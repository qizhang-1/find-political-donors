# %%
import pandas as pd
import numpy as np
import csv
filename = './itcont.txt'
pd.read_csv(filename, header=None, sep="|")
# Out:
#           0  1    2  3                   4    5    6                    7   \
# 0  C00629618  N  TER  P  201701230300133512  15C  IND        PEREZ, JOHN A
# 1  C00177436  N   M2  P  201702039042410894   15  IND    DEEHAN, WILLIAM N
# 2  C00384818  N   M2  P  201702039042412112   15  IND       ABBOTT, JOSEPH
# 3  C00177436  N   M2  P  201702039042410893   15  IND      SABOURIN, JAMES
# 4  C00177436  N   M2  P  201702039042410895   15  IND  JEROME, CHRISTOPHER
# 5  C00384818  N   M2  P  201702039042412112   15  IND         BAKER, SCOTT
# 6  C00177436  N   M2  P  201702039042410894   15  IND        FOLEY, JOSEPH
#
#                  8   9          ...                   11  \
# 0       LOS ANGELES  CA         ...            PRINCIPAL
# 1        ALPHARETTA  GA         ...                 UNUM
# 2        WOONSOCKET  RI         ...           CVS HEALTH
# 3  LOOKOUT MOUNTAIN  GA         ...                 UNUM
# 4          FALMOUTH  ME         ...                 UNUM
# ...

# %%
filename = './itcont.txt'
fileHandle = open(filename, 'r')
for line in fileHandle:
    fields = line.split('|')
fileHandle.close()
print(len(fields[:]))
# Out:
# 21
